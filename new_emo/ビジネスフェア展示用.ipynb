# %%
import whisper
import ffmpeg
import shap

# %%
model = whisper.load_model("base", device="cuda")
_ = model.half()
_ = model.cuda()

for m in model.modules():
    if isinstance(m, whisper.model.LayerNorm):
        m.float()

# %%
path = "./graduation.m4a"
# model = whisper.load_model("base")
path = "./last_week.m4a"
#path = "./kondo無題.m4a"

# %%
result = model.transcribe(path, verbose=True, language='ja')
# Out:
# [00:00.000 --> 00:05.720] おはようございます。先週はとても寒い日でした。

# %%
result.get("text")
# Out:
# 'おはようございます。先週はとても寒い日でした。'

# %%
from transformers import pipeline
classifier = pipeline("text-classification",model='bhadresh-savani/bert-base-uncased-emotion', return_all_scores=True)
prediction = classifier(result.get("text"))
# Out:
# `return_all_scores` is now deprecated,  if want a similar funcionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.

# %%
explainer = shap.Explainer(classifier)

# %%
# b = 'これは素晴らしい技術ですね。いまCFRP素材である航空機は増えておりますが様々な理由で破損・劣化した部分の修理はそのぶん積み重なってきて作業的に難しい材料なため高コストとなっていることかと思います。また、CFRPは航空機のみならず小型船舶でも一般的になってきていますし乗用車などでの採用例も今後増えてくる可能性があります。'

# %%
a = explainer(result.get("text").split('。'))

# %%
shap.plots.text(a)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_nfzwerackgownbtwhmrc = '_tp_nfzwerackgownbtwhmrc_output_0';
#     document._zoom_nfzwerackgownbtwhmrc = undefined;
#     function _output_onclick_nfzwerackgownbtwhmrc(i) {
#         var next_id = undefined;
#
#         if (document._zoom_nfzwerackgownbtwhmrc !== undefined) {
#             document.getElementById(document._zoom_nfzwerackgownbtwhmrc+ '_zoom').style.display = 'none';
#
#             if (document._zoom_nfzwerackgownbtwhmrc === '_tp_nfzwerackgownbtwhmrc_output_' + i) {
#                 document.getElementById(document._zoom_nfzwerackgownbtwhmrc).style.display = 'block';
# ...
